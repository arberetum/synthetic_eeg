# %%
import pickle
import matplotlib.pyplot as plt

filepath = "./outputs/WGAN/training_results_interictal_ncritic1_lr2e-05"
with open(filepath, 'rb') as f:
    results_ncrit1_lr2 = pickle.load(f)
print(results_ncrit1_lr2)

plt.plot(results_ncrit1_lr2['gen_losses'], label='Generator Loss')
plt.plot(results_ncrit1_lr2['disc_losses'], label='Critic Loss')
plt.legend()
plt.savefig(f"{filepath}_losses.png")
plt.show()


plt.plot(results_ncrit1_lr2['real_scores'], label='Real Score')
plt.plot(results_ncrit1_lr2['fake_scores'], label='Fake Score')
plt.legend()
plt.savefig(f"{filepath}_scores.png")
plt.show()
# Out:
# {'gen_losses': [-4.724274, -6.219353, 12.840686, -14.133939, -107.41288, -282.66837, -414.561, -746.39026, -937.8182, -1190.6499, -1156.1765, -999.7403, -1652.3318, -1772.9385, -1310.3162, -1799.9153, -1731.5828, -2345.4614, -1672.1133, -2479.926, -2421.7725, -2406.604, -1868.578, -2409.4233, -2867.2334, -2968.7014, -2531.2205, -3540.315, -3483.8828, -2174.4019, -2665.3025, -3094.9617, -2805.8723, -2688.3484, -3727.2332, -2921.4421, -3224.674, -3633.7197, -3002.9504, -3505.6167, -3444.2305, -3429.8647, -3739.0747, -3430.9973, -4529.1123, -4259.9785, -5305.0864, -4646.065, -4541.8984, -5532.5933], 'disc_losses': [-1.4182204, -9.444318, -34.20025, -57.436424, -52.50601, -63.062405, -145.17128, -257.68658, -202.68948, -209.41736, -136.46515, -303.0917, -444.19083, -112.71801, -305.59598, -373.75262, -302.38324, -298.00183, -296.91397, -406.7442, -230.23549, -370.7775, -291.0852, -403.83575, -170.05125, -410.99728, -368.46155, -358.73203, -252.65169, -458.2943, -257.064, -376.46558, -393
# ...

# %%
import pickle
import matplotlib.pyplot as plt

filepath = "./outputs/WGAN/training_results_interictal_ncritic1_lr5e-05"
with open(filepath, 'rb') as f:
    results_ncrit1_lr5 = pickle.load(f)
print(results_ncrit1_lr5)

plt.plot(results_ncrit1_lr5['gen_losses'], label='Generator Loss')
plt.plot(results_ncrit1_lr5['disc_losses'], label='Critic Loss')
plt.legend()
plt.savefig(f"{filepath}_losses.png")
plt.show()


plt.plot(results_ncrit1_lr5['real_scores'], label='Real Score')
plt.plot(results_ncrit1_lr5['fake_scores'], label='Fake Score')
plt.legend()
plt.savefig(f"{filepath}_scores.png")
plt.show()
# Out:
# {'gen_losses': [-26.215296, -282.42215, -946.39276, -1368.8279, -2108.4136, -2073.1233, -1979.8461, -2585.4817, -2390.8582, -2395.1423, -3100.046, -3541.0122, -3775.3208, -4260.4585, -3870.5854, -4772.1167, -4227.637, -4591.051, -4957.8813, -4872.4683, -5034.8784, -5048.403, -4606.901, -5379.5444, -6372.1963, -6685.0317, -7283.278, -7304.839, -6259.9077, -7369.336, -7458.661, -8363.429, -8287.256, -8321.082, -9235.065, -10610.86, -13602.073, -13940.347, -12764.702, -15244.756, -15433.922, -14242.777, -16918.05, -16345.13, -16245.83, -15255.317, -13950.089, -16418.502, -18551.803, -22157.38], 'disc_losses': [-4.426887, -66.76721, -360.50696, -292.31723, -379.5587, -368.6775, -408.30563, -349.58652, -338.48987, -377.60562, -308.82352, -324.21664, -380.1844, -408.72604, -445.71365, -475.6014, -402.64792, -405.90204, -461.7033, -506.2727, -390.0037, -394.12897, -467.0351, -517.684, -592.939, -571.53625, -649.8529, -602.89734, -482.3858, -554.1832, -542.1657, -654.0554, -653.17346, -635.1
# ...

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

filepath = "./outputs/WGAN/training_results_interictal_ncritic1_lr2e-05"
with open(filepath, 'rb') as f:
    results_ncrit1_lr2 = pickle.load(f)

filepath = "./outputs/WGAN/training_results_interictal_ncritic1_lr5e-05"
with open(filepath, 'rb') as f:
    results_ncrit1_lr5 = pickle.load(f)

filepath = "./outputs/WGAN/training_results_interictal_ncritic2_lr2e-05"
with open(filepath, 'rb') as f:
    results_ncrit2_lr2 = pickle.load(f)

filepath = "./outputs/WGAN/training_results_interictal_ncritic2_lr5e-05"
with open(filepath, 'rb') as f:
    results_ncrit2_lr5 = pickle.load(f)

filepath = "./outputs/WGAN/training_results_interictal_ncritic5_lr2e-05"
with open(filepath, 'rb') as f:
    results_ncrit5_lr2 = pickle.load(f)

filepath = "./outputs/WGAN/training_results_interictal_ncritic5_lr5e-05"
with open(filepath, 'rb') as f:
    results_ncrit5_lr5 = pickle.load(f)

plt.plot(-1*np.array(results_ncrit1_lr2['disc_losses']), label='n_critic = 1, lr = 2e-05')
plt.plot(-1*np.array(results_ncrit1_lr5['disc_losses']), label='n_critic = 1, lr = 5e-05')
plt.plot(-1*np.array(results_ncrit2_lr2['disc_losses']), label='n_critic = 2, lr = 2e-05')
plt.plot(-1*np.array(results_ncrit2_lr5['disc_losses']), label='n_critic = 2, lr = 5e-05')
plt.plot(-1*np.array(results_ncrit5_lr2['disc_losses']), label='n_critic = 5, lr = 2e-05')
plt.plot(-1*np.array(results_ncrit5_lr5['disc_losses']), label='n_critic = 5, lr = 5e-05')
plt.legend(fontsize='large')
plt.xlabel("Epoch", fontsize='large')
plt.ylabel("Negative Critic Loss", fontsize='large')
plt.savefig("./outputs/WGAN/wgan_neg_crit_loss_grid_search.png")
plt.show()

# %%
plt.plot(-1*np.array(results_ncrit1_lr2['disc_losses']), label='n_critic = 1, lr = 2e-05')
plt.plot(-1*np.array(results_ncrit2_lr2['disc_losses']), label='n_critic = 2, lr = 2e-05')
plt.show()

# %% [markdown]
# # Plots of Real Data

# %%
import matplotlib.pyplot as plt
import os
from scipy.io import loadmat
import numpy as np

def get_data_key_from_filename(filename):
    filename = filename.split("/")
    filename = filename[-1].split(".")
    filename = filename[0].split("_")
    filename = filename[2:]
    filename[-1] = filename[-1].lstrip("0")
    return "_".join(filename)

root_folder = "/Volumes/LACIE SHARE/seizure-prediction"
real_interictal_file = "Dog_1/Dog_1/Dog_1_interictal_segment_0009.mat"
real_preictal_file = "Dog_1/Dog_1/Dog_1_preictal_segment_0013.mat"

filepath = os.path.join(root_folder, real_interictal_file)
mat_data = loadmat(filepath)
signals_interictal = np.array(mat_data[get_data_key_from_filename(real_interictal_file)][0, 0][0])
signals_interictal = np.transpose(signals_interictal)   # convert so # timepoints x # channels
filepath = os.path.join(root_folder, real_preictal_file)
mat_data = loadmat(filepath)
signals_preictal = np.array(mat_data[get_data_key_from_filename(real_preictal_file)][0, 0][0])
signals_preictal = np.transpose(signals_preictal)   # convert so # timepoints x # channels

# crop out a ten second window
signals_interictal = signals_interictal[:4000, :]
signals_preictal = signals_preictal[:4000, :]

NUM_CHANNELS = signals_preictal.shape[1]

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111) 

for i in range(NUM_CHANNELS):
    plt.subplot(4, 4, i+1)
    plt.plot(signals_interictal[0:400, i])
    plt.title(f"Channel {i+1}")

ax.set_xlabel("Sample", fontsize='large')
ax.set_ylabel("Signal Value", fontsize='large')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/real_interictal_time.png")
plt.show()

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111) 

for i in range(NUM_CHANNELS):
    plt.subplot(4, 4, i+1)
    plt.plot(signals_preictal[0:400, i])
    plt.title(f"Channel {i+1}")

ax.set_xlabel("Sample", fontsize='large')
ax.set_ylabel("Signal Value", fontsize='large')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/real_preictal_time.png")
plt.show()

# %%
# need to run previous section first
# create spectrograms for channel 2

Fs = 399.6097561

Pxx, freqs, bins, im = plt.specgram(signals_interictal[:, 1], Fs=Fs)
plt.xlabel("Time (s)", fontsize='large')
plt.ylabel("Frequency (Hz)", fontsize='large')
plt.colorbar(im).set_label('Intensity (dB)', fontsize='large')
plt.ylim(0, 40)
plt.clim(-60,30)
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/real_interictal_spec.png")
plt.show()

Pxx, freqs, bins, im = plt.specgram(signals_preictal[:, 1], Fs=Fs)
plt.xlabel("Time (s)", fontsize='large')
plt.ylabel("Frequency (Hz)", fontsize='large')
plt.colorbar(im).set_label('Intensity (dB)', fontsize='large')
plt.ylim(0, 40)
plt.clim(-60,30)
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/real_preictal_spec.png")
plt.show()

# %% [markdown]
# # Plots of WGAN Data

# %%
import matplotlib.pyplot as plt
import os
from scipy.io import loadmat
import numpy as np

signals_interictal = np.load("./interictal_set1.npy")
signals_preictal = np.load("./preictal_set1.npy")
signals_interictal = signals_interictal[0:4000,:]
signals_preictal = signals_preictal[0:4000,:]

NUM_CHANNELS = signals_preictal.shape[1]

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111) 

for i in range(NUM_CHANNELS):
    plt.subplot(4, 4, i+1)
    plt.plot(signals_interictal[0:400, i])
    plt.title(f"Channel {i+1}")

ax.set_xlabel("Sample", fontsize='large')
ax.set_ylabel("Signal Value", fontsize='large')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/wgan_interictal_time.png")
plt.show()

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111) 

for i in range(NUM_CHANNELS):
    plt.subplot(4, 4, i+1)
    plt.plot(signals_preictal[0:400, i])
    plt.title(f"Channel {i+1}")

ax.set_xlabel("Sample", fontsize='large')
ax.set_ylabel("Signal Value", fontsize='large')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/wgan_preictal_time.png")
plt.show()

Pxx, freqs, bins, im = plt.specgram(signals_interictal[:, 1], Fs=Fs)
plt.xlabel("Time (s)", fontsize='large')
plt.ylabel("Frequency (Hz)", fontsize='large')
plt.colorbar(im).set_label('Intensity (dB)', fontsize='large')
plt.ylim(0, 40)
plt.clim(-60,30)
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/wgan_interictal_spec.png")
plt.show()

Pxx, freqs, bins, im = plt.specgram(signals_preictal[:, 1], Fs=Fs)
plt.xlabel("Time (s)", fontsize='large')
plt.ylabel("Frequency (Hz)", fontsize='large')
plt.colorbar(im).set_label('Intensity (dB)', fontsize='large')
plt.ylim(0, 40)
plt.clim(-60,30)
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/wgan_preictal_spec.png")
plt.show()

# %% [markdown]
# # Plots of DDPM Data

# %%
import matplotlib.pyplot as plt
import os
from scipy.io import loadmat
import numpy as np

X_min_preictal = -2147
X_max_preictal = 2081
X_min_interictal = -2153
X_max_interictal = 1925
signals_interictal = np.load("/Volumes/LACIE SHARE/seizure-prediction-outputs/generated_samples_interictal_ddpm.npy")
signals_preictal = np.load("/Volumes/LACIE SHARE/seizure-prediction-outputs/generated_samples_preictal_ddpm.npy")
signals_interictal = np.transpose(np.squeeze(signals_interictal[0, :, :4000])) * (X_max_interictal - X_min_interictal) + X_min_interictal
signals_preictal = np.transpose(np.squeeze(signals_preictal[0, :, :4000])) * (X_max_preictal - X_min_preictal) + X_min_preictal

NUM_CHANNELS = signals_preictal.shape[1]

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111) 

for i in range(NUM_CHANNELS):
    plt.subplot(4, 4, i+1)
    plt.plot(signals_interictal[0:400, i])
    plt.title(f"Channel {i+1}")

ax.set_xlabel("Sample", fontsize='large')
ax.set_ylabel("Signal Value", fontsize='large')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/ddpm_interictal_time.png")
plt.show()

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111) 

for i in range(NUM_CHANNELS):
    plt.subplot(4, 4, i+1)
    plt.plot(signals_preictal[0:400, i])
    plt.title(f"Channel {i+1}")

ax.set_xlabel("Sample", fontsize='large')
ax.set_ylabel("Signal Value", fontsize='large')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/ddpm_preictal_time.png")
plt.show()

Pxx, freqs, bins, im = plt.specgram(signals_interictal[:, 1], Fs=Fs)
plt.xlabel("Time (s)", fontsize='large')
plt.ylabel("Frequency (Hz)", fontsize='large')
plt.colorbar(im).set_label('Intensity (dB)', fontsize='large')
plt.ylim(0, 40)
# plt.clim(-60,30)
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/ddpm_interictal_spec.png")
plt.show()

Pxx, freqs, bins, im = plt.specgram(signals_preictal[:, 1], Fs=Fs)
plt.xlabel("Time (s)", fontsize='large')
plt.ylabel("Frequency (Hz)", fontsize='large')
plt.colorbar(im).set_label('Intensity (dB)', fontsize='large')
plt.ylim(0, 40)
# plt.clim(-60,30)
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/ddpm_preictal_spec.png")
plt.show()

# %% [markdown]
# # Final WGAN Loss Curves

# %%
import pickle

interictal_results_file = "/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/WGAN/interictal/training_results_interictal_ncritic1_lr2e-05_200epochs"
preictal_results_file = "/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/WGAN/preictal/training_results_preictal_ncritic1_lr2e-05"

with open(interictal_results_file, 'rb') as f:
    interictal_results = pickle.load(f)
with open(preictal_results_file, 'rb') as f:
    preictal_results = pickle.load(f)

print(interictal_results.keys())

plt.plot(-1*np.array(interictal_results['disc_losses']), label="Train")
plt.plot(-1*np.array(interictal_results['val_losses']), label="Validation")
plt.xlabel("Epoch", fontsize='large')
plt.ylabel("Negative Critic Loss", fontsize='large')
plt.legend(fontsize='large')
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/WGAN/interictal/wgan_interictal_critic_loss_curves.png")
plt.show()

plt.plot(-1*np.array(preictal_results['disc_losses']), label="Train")
plt.plot(-1*np.array(preictal_results['val_losses']), label="Validation")
plt.xlabel("Epoch", fontsize='large')
plt.ylabel("Negative Critic Loss", fontsize='large')
plt.legend(fontsize='large')
plt.savefig("/Users/aidenmaloney-bertelli/Documents/CS534/final/git/synthetic_eeg/outputs/WGAN/preictal/wgan_preictal_critic_loss_curves.png")
plt.show()
# Out:
# dict_keys(['gen_losses', 'disc_losses', 'real_scores', 'fake_scores', 'val_losses'])
